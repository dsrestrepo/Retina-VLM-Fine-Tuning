# %%
import pandas as pd

# %%
import os

# %%
path = "results/evals"
counter = 0
for file in os.listdir(path):
    if 'cot' in file:
        continue
    df = pd.read_csv(os.path.join(path, file))
    print(file)
    #print(f"Unique answers: {df.prediction_text.unique()}")
    print(f"{len(df.prediction_text.unique())} unique answers")
# Out:
# brset_binary_dr_role_google_medgemma-4b-it.csv
# 2 unique answers
# mbrset_referable_dr_role_Qwen_Qwen3-VL-8B-Instruct.csv
# 3 unique answers
# mbrset_referable_dr_role_llava-hf_llama3-llava-next-8b-hf.csv
# 2 unique answers
# brset_binary_dr_google_medgemma-4b-it.csv
# 2 unique answers
# brset_binary_dr_role_Qwen_Qwen3-VL-8B-Instruct.csv
# 4 unique answers
# brset_referable_dr_role_llava-hf_llama3-llava-next-8b-hf.csv
# 2 unique answers
# mbrset_referable_dr_google_medgemma-1.5-4b-it.csv
# 1 unique answers
# mbrset_binary_dr_google_medgemma-1.5-4b-it.csv
# 19 unique answers
# mbrset_binary_dr_role_Qwen_Qwen3-VL-8B-Instruct.csv
# 5 unique answers
# mbrset_referable_dr_meta-llama_Llama-3.2-11B-Vision-Instruct.csv
# 114 unique answers
# mbrset_referable_dr_role_google_medgemma-1.5-4b-it.csv
# 1 unique answers
# brset_referable_dr_role_google_medgemma-1.5-4b-it.csv
# 2 unique answers
# brset_referable_dr_role_Qwen_Qwen3-VL-8B-Instruct.csv
# 3 unique answers
# ...

# %%
# Out:
# array(['no', 'yes',
#        'Based on the provided information, the patient has macular edema. Therefore, the answer is **yes**.'],
#       dtype=object)
